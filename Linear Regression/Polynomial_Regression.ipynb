# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Data section

# %%
df=pd.read_csv("polynomial_regression_dataset.csv")
X=df[['x']]
Y=df['y']

# %% [markdown]
# Fit the values

# %%
poly_features = PolynomialFeatures(degree=2) 
X_poly=poly_features.fit_transform(X)
model=LinearRegression()
model.fit(X_poly,Y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_poly)
y_pred
# Out:
# array([ 4.61647139e+03,  4.01750688e+03,  3.14532312e+03,  2.39150718e+03,
#         1.62415713e+03,  9.83021059e+02,  2.04208604e+02, -4.03059426e+01,
#        -4.14301999e+02, -7.23697351e+02, -8.75581957e+02, -9.34555159e+02,
#        -9.02643372e+02, -7.38479573e+02, -5.01369161e+02, -8.82206538e+01,
#         4.17817292e+02,  1.06807213e+03,  1.75278416e+03,  2.64313139e+03,
#         3.66058636e+03,  4.67169852e+03,  5.78324148e+03,  7.15377350e+03,
#         8.47873193e+03,  1.00893564e+04,  1.17604614e+04,  1.36205936e+04,
#         1.56078336e+04,  1.75612039e+04,  1.95389626e+04,  2.17059228e+04,
#         2.38887277e+04,  2.62692777e+04,  2.86571288e+04,  3.12512687e+04,
#         3.40647741e+04,  3.71112453e+04,  3.99259273e+04,  4.28410402e+04,
#         4.57289311e+04,  4.92367562e+04,  5.27347953e+04,  5.62094482e+04,
#         5.96476382e+04,  6.31862590e+04,  6.68253106e+04,  7.10392898e+04,
#         7.47292323e+04,  7.90115383e+04])

# %% [markdown]
# Predict a value

# %%
x_new=[[107]]
x_new_poly=poly_features.fit_transform(x_new)
print(model.predict(x_new_poly))
# Out:
# [54389.02868175]

# %% [markdown]
# Scatter and plotting the the values and regression line

# %%
plt.scatter(X,Y)
plt.plot(X,y_pred,color='green')
plt.show()

# %% [markdown]
# Value of R-Squared

# %%
import numpy
from sklearn.metrics import r2_score

x=df['x']

mymodel = numpy.poly1d(numpy.polyfit(x,Y,2))

print(r2_score(Y, mymodel(X)))
# Out:
# 0.9873532370088727
